# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Data Analysis of Singapore Rainfall

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# ### Choose your Data
#
# There are 2 datasets included in the [`data`](./data/) folder for this project. These correponds to rainfall information.
#
# * [`rainfall-monthly-number-of-rain-days.csv`](./data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](./data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022
#
# Other relevant weather datasets from [data.gov.sg](data.gov.sg) that you can download and use are as follows:
#
# * [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)
# * [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)
# * [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)
# * [Monthly mean sunshine hours](https://data.gov.sg/dataset/sunshine-duration-monthly-mean-daily-duration)
# * [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)
#
# You can also use other datasets for your analysis, make sure to cite the source when you are using them

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
# [Monthly Hospital Admissions](https://tablebuilder.singstat.gov.sg/table/TS/M870041)
# - I will be using the columns for hospital admissions for each of the listed hospitals and the total admissions.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
#
#
# **To-Do:**
#
# ### Context
# As the world is in the midst of climatic change, Singapore is experiencing increased frequencies of heavy rains and new record high temperatures. Our hospitals have experienced a surge in patients over the last years and more hospital beds are required. One of the several reasons a person can get inpatient care is getting in contact with a pathogen which causes the person to be infected. The endemic COVID-19 is a an example of an outbreak. Therefore, this project aims to analyse the Singapore's climate patterns from the year 1987 to 2022 and its relationship to hospital admissions.
#
#
# ### Problem Statement
#
# #### Hospital management to efficiently plan manpower and bed allocations in our local hospitals by analyzing the relationship of between climate data with hospital admissions.
#
# source: https://tablebuilder.singstat.gov.sg/table/TS/M870041
#
# source 1: https://www.straitstimes.com/singapore/healthcare-system-still-stretched-even-as-spores-daily-covid-19-case-count-dips
#
# source 2: https://www.who.int/news-room/fact-sheets/detail/climate-change-and-health#:~:text=Climate%20change%20affects%20food%20availability,700%20000%20annually%2C%20may%20rise.
#
#
# #### Audience
#
# Hospital administrators in the healthcare sector.

# %% [markdown]
# Rainfall affects daily activities of Singapore population, hence it is worth analysing rainfall data to identify trends

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on how climate change is affecting different industries or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:**
#
# https://www.weather.gov/lmk/humidity
#
# https://www.straitstimes.com/singapore/bed-crunch-at-singapore-hospitals-some-patients-are-stuck-in-emergency-departments
#
# https://www.moh.gov.sg/docs/librariesprovider5/resources-statistics/reports/special_feature_sars.pdf
#
# https://www.nea.gov.sg/dengue-zika/dengue/dengue-cases
#
# https://www.ncbi.nlm.nih.gov/books/NBK222258/
#
# Chan, K.-H. (2011). The Effects of Temperature and Relative Humidity on the Viability of the SARS Coronavirus. Advances in Virology, 2011, 734690. doi:10.1155/2011/734690 https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3265313/
#
# Campbell, K. M., Lin, C. D., Iamsirithaworn, S., & Scott, T. W. (2013). The complex relationship between weather and dengue virus transmission in Thailand. The American Journal of Tropical Medicine and Hygiene, 89(6), 1183-1193.
#
# The Effects of Temperature and Relative Humidity on the Viability of the SARS Coronavirus
# K.H.Chan, J. S. Malik Peiris, S. Y. Lam, L. L. M. Poon, K.Y.Yuen, and W.H. Seto (2011)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# define a function to return the mean of a list of values.
def get_mean(list_of_values):

    total = 0
    for num in list_of_values:
        total += num
    return total / len(list_of_values)

some_list = [2,4,6,8,10,12,14] # example list

### To check if the function behaves as it should ###

import numpy as np
print(f'''
The mean from the function created for the values in some_list is: {get_mean(some_list)}.
Now compare the mean from the python library using the same list if the values are identical: {np.mean(some_list)}.
''')
# Out:
# The mean from the function created for the values in some_list is: 8.0.
# Now compare the mean from the python library using the same list if the values are identical: 8.0.

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# using the get_mean() function that was created earlier we add on to another function to obtain the standard deviation

def get_std_dev(list_of_values):

    # get the mean
    the_mean = get_mean(list_of_values)
    
    # calculate the sum of squares
    sum_squares = 0
    for num in list_of_values:
        sum_squares += (num - the_mean)**2

    std_dev = (1/len(list_of_values) * sum_squares)**0.5


    return std_dev

some_list = [2,4,6,8,10,12,14] # example list
get_std_dev(some_list) # call the function on the example list

### To check if the function behaves as it should ###

print(f'''
The standard deviation from the function created for the values in some_list is: {get_std_dev(some_list)}.
Now compare the standard deviation from the python library using the same list if the values are identical: {np.std(some_list)}.
''')
# Out:
# The standard deviation from the function created for the values in some_list is: 4.0.
# Now compare the standard deviation from the python library using the same list if the values are identical: 4.0.

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# to allow all columns to be viewed in a row
pd.set_option('display.width', 10000)
# to allow all columns to be displayed
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import all the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary. Make sure to comment your code to showcase the intent behind the data processing step.
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values and datatype.
# 3. Check for any obvious issues with the observations.
# 4. Fix any errors you identified in steps 2-3.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If the month column data is better analyzed as month and year, create new columns for the same
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
#     - Since different climate metrics are in month format, you can merge them into one single dataframe for easier analysis
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# import data

surface_air_temp_df = pd.read_csv('../data/surface-air-temperature-monthly-mean.csv')
num_raindays_df = pd.read_csv('../data/rainfall-monthly-number-of-rain-days.csv')
highest_rain_month_df = pd.read_csv('../data/rainfall-monthly-highest-daily-total.csv')
rainfall_monthly_total_df = pd.read_csv('../data/rainfall-monthly-total.csv')
relative_humidity_df = pd.read_csv('../data/relative-humidity-monthly-mean.csv')
sunshine_duration_df = pd.read_csv('../data/sunshine-duration-monthly-mean-daily-duration.csv')


print(highest_rain_month_df.head())
# Out:
#      month  maximum_rainfall_in_a_day
# 0  1982-01                       36.5
# 1  1982-02                        9.4
# 2  1982-03                       61.7
# 3  1982-04                       45.1
# 4  1982-05                       33.0

# %%
combined_df = surface_air_temp_df.merge(num_raindays_df, how='inner', left_on='month', right_on='month')
combined_df = combined_df.merge(highest_rain_month_df, how = 'inner', left_on='month', right_on='month')
combined_df = combined_df.merge(rainfall_monthly_total_df, how = 'inner', left_on='month', right_on='month')
combined_df = combined_df.merge(relative_humidity_df, how = 'inner', left_on='month', right_on='month')
combined_df = combined_df.merge(sunshine_duration_df, how = 'inner', left_on='month', right_on='month')

print(combined_df.head())
print()

print(combined_df.info())
# Out:
#      month  mean_temp  no_of_rainy_days  maximum_rainfall_in_a_day  total_rainfall  mean_rh  mean_sunshine_hrs
# 0  1982-01       25.9                10                       36.5           107.1     81.2                5.6
# 1  1982-02       27.1                 5                        9.4            27.8     79.5                7.6
# 2  1982-03       27.2                11                       61.7           160.8     82.3                5.1
# 3  1982-04       27.0                14                       45.1           157.0     85.9                4.7
# 4  1982-05       28.0                10                       33.0           102.2     83.2                5.8
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      488 non-null    object
# ...

# %%
# Import hospitalisation data

hospital_df = pd.read_csv('../data/hospital2.csv')

print(hospital_df.head()) # inspect first 5 rows of data
# Out:
#   Data Series  Public Sector Hospital Admissions Alexandra Hospital Changi General Hospital Khoo Teck Puat Hospital  National University Hospital Ng Teng Fong General Hospital Sengkang General Hospital  Singapore General Hospital  Tan Tock Seng Hospital Communicable Disease Centre National Centre For Infectious Diseases  Institute Of Mental Health / Woodbridge Hospital  Kandang Kerbau Women's & Children's Hospital National Heart Centre
# 0    2023 Dec                              43954               1058                    4700                    4104                          6262                          3517                      4542                        6436                    5051                          na                                     693                                               824                                          6002                   765
# ...

# %%
print(hospital_df.info())

# There are no null values but there are 'n.a' in the dataset, so n.a is string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 15 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Data Series                                       444 non-null    object
#  1   Public Sector Hospital Admissions                 444 non-null    int64
#  2   Alexandra Hospital                                444 non-null    object
#  3   Changi General Hospital                           444 non-null    object
#  4   Khoo Teck Puat Hospital                           444 non-null    object
#  5   National University Hospital                      444 non-null    int64
#  6   Ng Teng Fong General Hospital                     444 non-null    object
#  7   Sengkang General Hospital                         444 non-null    object
#  8   Singapore General Hospital                        444 non-null    int64
# ...

# %%
# rename the column headers

column_header = ['month_year', 'total_admissions', 'ah', 'cgh', 'ktph', 'nuh', 'ntfgh', 'skgh', 'sgh', 'ttsh', 'cdc', 'ncid', 'imh', 'kkh', 'nhc']

hospital_df.columns = column_header


print(hospital_df.head()) # check if the column headers are correct
# Out:
#   month_year  total_admissions    ah   cgh  ktph   nuh ntfgh  skgh   sgh  ttsh cdc ncid  imh   kkh  nhc
# 0   2023 Dec             43954  1058  4700  4104  6262  3517  4542  6436  5051  na  693  824  6002  765
# 1   2023 Nov             42500   861  4502  4020  6090  3432  4262  6344  4887  na  363  846  6099  794
# 2   2023 Oct             44532   923  4651  4228  6283  3630  4439  6743  4947  na  366  932  6584  806
# 3   2023 Sep             42655   852  4515  4047  5942  3489  4275  6468  4887  na  264  871  6322  723
# 4   2023 Aug             45094   957  4877  4153  6354  3711  4492  6764  5345  na  199  910  6532  800

# %%
# reverse the order to do by chronological order
hospital_df = hospital_df.iloc[::-1].reset_index(drop=True)


print(hospital_df.head())
# Out:
#   month_year  total_admissions    ah cgh ktph   nuh ntfgh skgh   sgh  ttsh cdc ncid  imh   kkh nhc
# 0   1987 Jan             18822  2345  na   na  1864    na   na  5224  3937  na   na  493  2412  na
# 1   1987 Feb             19074  2188  na   na  1862    na   na  5490  4061  na   na  480  2420  na
# 2   1987 Mar             22173  2641  na   na  2584    na   na  6447  4128  na   na  518  2892  na
# 3   1987 Apr             19797  2348  na   na  2202    na   na  5761  3804  na   na  498  2686  na
# 4   1987 May             19602  2357  na   na  2032    na   na  5754  3629  na   na  469  2739  na

# %%
# reformat the month-year to yyyy-mm
# only can run once else an error is thrown

hospital_df['month_year'] = pd.to_datetime(hospital_df['month_year'], format ='%Y %b').dt.strftime('%Y-%m')

print(hospital_df.head())
# Out:
#   month_year  total_admissions    ah cgh ktph   nuh ntfgh skgh   sgh  ttsh cdc ncid  imh   kkh nhc
# 0    1987-01             18822  2345  na   na  1864    na   na  5224  3937  na   na  493  2412  na
# 1    1987-02             19074  2188  na   na  1862    na   na  5490  4061  na   na  480  2420  na
# 2    1987-03             22173  2641  na   na  2584    na   na  6447  4128  na   na  518  2892  na
# 3    1987-04             19797  2348  na   na  2202    na   na  5761  3804  na   na  498  2686  na
# 4    1987-05             19602  2357  na   na  2032    na   na  5754  3629  na   na  469  2739  na

# %%
## To convert hospital admission columns from object to integer values

# select the al hospitals in the dataframe
hospitals = hospital_df.columns[:1:-1]
print(hospitals) # check all hospitals are selected

# using a for-loop to loop all hospitals
for hos in hospitals:
    # replace all 'na' values to 0
    hospital_df[hos] = hospital_df[hos].replace('na', 0)
    # convert the column to integer type
    hospital_df[hos] = hospital_df[hos].astype(int)


print(hospital_df.info())
print(hospital_df.head())
# Out:
# Index(['nhc', 'kkh', 'imh', 'ncid', 'cdc', 'ttsh', 'sgh', 'skgh', 'ntfgh', 'nuh', 'ktph', 'cgh', 'ah'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month_year        444 non-null    object
#  1   total_admissions  444 non-null    int64
#  2   ah                444 non-null    int64
#  3   cgh               444 non-null    int64
#  4   ktph              444 non-null    int64
#  5   nuh               444 non-null    int64
#  6   ntfgh             444 non-null    int64
#  7   skgh              444 non-null    int64
#  8   sgh               444 non-null    int64
#  9   ttsh              444 non-null    int64
#  10  cdc               444 non-null    int64
#  11  ncid              444 non-null    int64
#  12  imh               444 non-null    int64
#  13  kkh               444 non-null    int64
# ...

# %%
# The earliest data from climate data is 1982-01 but the earliest for hospital dataframe is 1987-01
# we will have to match the years to 1987-01

final_df = combined_df.merge(hospital_df, how='inner', left_on='month', right_on='month_year')

# inspection of final dataframe
print(final_df.head())
# Out:
#      month  mean_temp  no_of_rainy_days  maximum_rainfall_in_a_day  total_rainfall  mean_rh  mean_sunshine_hrs month_year  total_admissions    ah  cgh  ktph   nuh  ntfgh  skgh   sgh  ttsh  cdc  ncid  imh   kkh  nhc
# 0  1987-01       25.5                16                      127.4           568.6     86.0                4.0    1987-01             18822  2345    0     0  1864      0     0  5224  3937    0     0  493  2412    0
# 1  1987-02       26.6                 7                       34.8            86.9     79.0                9.2    1987-02             19074  2188    0     0  1862      0     0  5490  4061    0     0  480  2420    0
# 2  1987-03       27.5                12                       40.9           132.5     83.2                6.9    1987-03             22173  2641    0     0  2584      0     0  6447  4128    0     0  518  2892    0
# ...

# %%
# to separate the year and month into their own list

year = []
sep_months = []

for row in final_df['month']:
    year_month = row.split('-')
    year.append(year_month[0])
    sep_months.append(year_month[1])

# insert the list of separated year and month into the dataframe at index 0 and 1
final_df.insert(0, 'year', year, True)
final_df.insert(1,'sep_month', sep_months, True)

# clean the month column headers
final_df = final_df.rename(columns = {'sep_month': 'month',
                            'month': 'year_month'})

print(final_df.head())


print(final_df.shape) # 488 rows, 24 columns
# Out:
#    year month year_month  mean_temp  no_of_rainy_days  maximum_rainfall_in_a_day  total_rainfall  mean_rh  mean_sunshine_hrs month_year  total_admissions    ah  cgh  ktph   nuh  ntfgh  skgh   sgh  ttsh  cdc  ncid  imh   kkh  nhc
# 0  1987    01    1987-01       25.5                16                      127.4           568.6     86.0                4.0    1987-01             18822  2345    0     0  1864      0     0  5224  3937    0     0  493  2412    0
# 1  1987    02    1987-02       26.6                 7                       34.8            86.9     79.0                9.2    1987-02             19074  2188    0     0  1862      0     0  5490  4061    0     0  480  2420    0
# 2  1987    03    1987-03       27.5                12                       40.9           132.5     83.2                6.9    1987-03             22173  2641    0     0  2584      0     0  6447  4128    0     0  518  2892    0
# ...

# %%
# drop extra date from hospital dataframe
final_df = final_df.drop(columns='month_year')

print(final_df.info()) # check that it has been dropped
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       428 non-null    object
#  1   month                      428 non-null    object
#  2   year_month                 428 non-null    object
#  3   mean_temp                  428 non-null    float64
#  4   no_of_rainy_days           428 non-null    int64
#  5   maximum_rainfall_in_a_day  428 non-null    float64
#  6   total_rainfall             428 non-null    float64
#  7   mean_rh                    428 non-null    float64
#  8   mean_sunshine_hrs          428 non-null    float64
#  9   total_admissions           428 non-null    int64
#  10  ah                         428 non-null    int64
#  11  cgh                        428 non-null    int64
#  12  ktph                       428 non-null    int64
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |year| object | surface-air-temperature-monthly-mean | The year in YYYY format |
# |month|object|surface-air-temperature-monthly-mean| The month in MM format |
# |year_month|object|surface-air-temperature-monthly-mean| The year and month in YYYY-MM  format|
# |mean_temp|float|surface-air-temperature-monthly-mean| Mean air temperature in Celcius|
# |no_of_rainy_days| int64| rainfall-monthly-number-of-rain-days | Number of rainy days in a month|
# |maximum_rainfall_in_a_day| float | rainfall-monthly-highest-daily-total | The highest rainfall in a day (mL)|
# |total_rainfall|float|rainfall-monthly-total|Total rainfall in mm|
# | mean_rh | float | relative-humidity-monthly-mean | Mean relative humidity in a month (%)|
# | mean_sunshine_hrs | float | relative-humidity-monthly-mean | The amount of sunlight in a day (hrs)|
# | ah | int | hospital2 | The number of patients admitted in a month fo Alexandra Hospital |
# | cgh | int | hospital2 | The number of patients admitted in a month for Changi General Hospital|
# | ktph | int | hospital2 | The number of patients admitted in a month for Khoo Teck Puat Hospital|
# | nuh | int | hospital2 | The number of patients admitted in a month for National University Hospital|
# | ntfgh | int | hospital2 | The number of patients admitted in a month for Ng Teng Fong General Hospital|
# | skgh | int | hospital2 | The number of patients admitted in a month for SengKang General Hospital|
# | sgh | int | hospital2 | The number of patients admitted in a month for Singapore General Hospital|
# | tsh | int | hospital2 | The number of patients admitted in a month for Tan Tock Seng Hospital|
# | cdc | int | hospital2 | The number of patients admitted in a month for Communicable Disease Centre|
# | ncid | int | hospital2 | The number of patients admitted in a month National Centre for Infectious Diseases|
# | imh | int | hospital2 | The number of patients admitted in a month for the Institute of Mental Health|
# | kkh | int | hospital2 | The number of patients admitted in a month for Kandang Kerbau Women's and Children's Hospital|
# | nhc | int | hospital2 | The number of patients admitted in a month for National Heart Centre|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'rainfall-monthly-total': xxx, 'no_of_rainy_days': xxx, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?
#
#     - **The above 5 questions are compulsory. Feel free to explore other trends based on the datasets that you have choosen for analysis. You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Using dictionary comprehension to obtain the standard deviation for each feature except month.
sd = {x: get_std_dev(final_df[x]) for x in final_df.columns if x not in ['year', 'month', 'year_month']}
sd
# Out:
# {'mean_temp': 0.7723952760073439,
#  'no_of_rainy_days': 4.921673929517787,
#  'maximum_rainfall_in_a_day': 35.26915937612526,
#  'total_rainfall': 113.85168205526354,
#  'mean_rh': 3.485756386657783,
#  'mean_sunshine_hrs': 1.1859889492547513,
#  'total_admissions': 6176.119744214589,
#  'ah': 527.8851174629207,
#  'cgh': 1634.3788574929176,
#  'ktph': 1544.7371403705556,
#  'nuh': 908.680028817883,
#  'ntfgh': 1312.7695345297163,
#  'skgh': 1103.786093721251,
#  'sgh': 695.0267804193181,
#  'ttsh': 594.9403283117405,
#  'cdc': 133.12504774694992,
#  'ncid': 249.31245810096667,
#  'imh': 117.29470916426689,
#  'kkh': 1208.570474268814,
#  'nhc': 381.0378046102914}

# %% [markdown]
# ## 1. Which month have the highest and lowest total rainfall in 1990, 2000, 2010, and 2020?

# %%
# Function to obtain the month where rainfall is the greatest and lowest

def get_min_max(some_df, some_year, some_feature):

    month_names = {
    '01': 'January',
    '02': 'February',
    '03': 'March',
    '04': 'April',
    '05': 'May',
    '06': 'June',
    '07': 'July',
    '08': 'August',
    '09': 'September',
    '10': 'October',
    '11': 'November',
    '12': 'December'
}

    
    year = [row for index, row in some_df.iterrows() if row['year'] == some_year]

    year = pd.DataFrame(year) # convert to DataFrame
    #print(year) # debug

    max_rainfall = year[some_feature].max()
    min_rainfall = year[some_feature].min()

    for index, row in year.iterrows():
        if row[some_feature] == max_rainfall:
            max_rainfall_month = row['month']

        if row[some_feature] == min_rainfall:
            min_rainfall_month = row['month']

    return f'In {some_year} the greatest {some_feature} is {month_names[max_rainfall_month]} and the lowest {some_feature} is in {month_names[min_rainfall_month]} of the year.'


# Obtain greatest and lowest rainfall month for 1990
get_min_max(final_df, '1990', 'total_rainfall')
# Out:
# 'In 1990 the greatest total_rainfall is September and the lowest total_rainfall is in February of the year.'

# %%
# Obtain greatest and lowest rainfall month for 2000
get_min_max(final_df, '2000','total_rainfall')
# Out:
# 'In 2000 the greatest total_rainfall is November and the lowest total_rainfall is in September of the year.'

# %%
# Obtain greatest and lowest rainfall month for 
get_min_max(final_df, '2010','total_rainfall')
# Out:
# 'In 2010 the greatest total_rainfall is July and the lowest total_rainfall is in February of the year.'

# %%
# Obtain greatest and lowest rainfall month for 2020
get_min_max(final_df, '2020','total_rainfall')
# Out:
# 'In 2020 the greatest total_rainfall is May and the lowest total_rainfall is in February of the year.'

# %% [markdown]
# ## 2. Which year have the highest and lowest total rainfall in the date range of analysis?

# %%
years = range(1982,2023)

highest_rainfall = final_df['total_rainfall'].max()
lowest_rainfall = final_df['total_rainfall'].min()

highest_rainfall_year_month = ''
lowest_rainfall_year_month = ''
for year in years:
    for index, row in final_df.iterrows():
        if row['total_rainfall'] == highest_rainfall:
            highest_rainfall_year_month = row['year_month']

for year in years:
    for index, row in final_df.iterrows():
        if row['total_rainfall'] == lowest_rainfall:
            lowest_rainfall_year_month = row['year_month']



print(highest_rainfall, highest_rainfall_year_month)
print(lowest_rainfall, lowest_rainfall_year_month)
# Out:
# 765.9 2006-12
# 0.2 2014-02

# %% [markdown]
# The year 2006 of December saw the highest total rainfall of 765.9 millilitres.
#
#
# The year 2014 of February had the lowest total rainfall of 0.2 millilitres.

# %% [markdown]
# ## 3. Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?

# %%
# What is the highest and lowest number of rainy days in 1990

get_min_max(final_df, '1990', 'no_of_rainy_days')
# Out:
# 'In 1990 the greatest no_of_rainy_days is November and the lowest no_of_rainy_days is in March of the year.'

# %%
# What is the highest and lowest number of rainy days in 2000

get_min_max(final_df, '2000', 'no_of_rainy_days')
# Out:
# 'In 2000 the greatest no_of_rainy_days is November and the lowest no_of_rainy_days is in May of the year.'

# %%
# What is the highest and lowest number of rainy days in 2010

get_min_max(final_df, '2010', 'no_of_rainy_days')
# Out:
# 'In 2010 the greatest no_of_rainy_days is November and the lowest no_of_rainy_days is in February of the year.'

# %%
# What is the highest and lowest number of rainy days in 2020

get_min_max(final_df, '2020', 'no_of_rainy_days')
# Out:
# 'In 2020 the greatest no_of_rainy_days is July and the lowest no_of_rainy_days is in January of the year.'

# %% [markdown]
# ### Which year have the highest and lowest number of rainy days in the date range of analysis?

# %%
years = range(1982,2023)

highest_num_rain_days = final_df['no_of_rainy_days'].max()
lowest_num_rain_days = final_df['no_of_rainy_days'].min()

highest_raindays_year_month = ''
lowest_raindays_year_month = ''
for year in years:
    for index, row in final_df.iterrows():
        if row['no_of_rainy_days'] == highest_num_rain_days:
            highest_raindays_year_month = row['year_month']

for year in years:
    for index, row in final_df.iterrows():
        if row['no_of_rainy_days'] == lowest_num_rain_days:
            lowest_raindays_year_month = row['year_month']



print(highest_num_rain_days, highest_raindays_year_month)
print(lowest_num_rain_days, lowest_raindays_year_month)
# Out:
# 27 2018-11
# 1 2014-02

# %% [markdown]
# The year 2018 in November saw the most number of rainy days coming at 27 days.
# The year 2014 in February saw the least number of rainy days with only 1 rainy day.

# %% [markdown]
# ### Are there any outliers months in the dataset?

# %%
print(final_df.describe())
# Out:
#         mean_temp  no_of_rainy_days  maximum_rainfall_in_a_day  total_rainfall     mean_rh  mean_sunshine_hrs  total_admissions           ah          cgh         ktph          nuh        ntfgh         skgh          sgh         ttsh         cdc         ncid         imh          kkh         nhc
# count  428.000000        428.000000                 428.000000      428.000000  428.000000         428.000000        428.000000   428.000000   428.000000   428.000000   428.000000   428.000000   428.000000   428.000000   428.000000  428.000000   428.000000  428.000000   428.000000  428.000000
# mean    27.745794         14.114486                  52.525935      177.976168   82.143692           5.712617      27725.425234  1332.815421  2487.880841  1085.577103  4258.490654   651.581776   389.226636  6346.303738  4123.441589  201.151869    67.719626  638.483645  4802.953271  525.607477
# ...

# %% [markdown]
# If the max or min is 3 standard deviations away from the mean, it indicates there is outlier in the for rainfall data
#
# columns containing outliers:
# - mean_temp
# - maximum_rainfall_in_a_day
# - total_rainfall

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %% [markdown]
# ## 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.

# %% [markdown]
# Before we proceed with the Exploratory Data Analysis (EDA), it is worth noting that the period of analysis is from January 1987 to August of 2022. Even though there are more data available for hospital admissions, the dataset is constrained by the climate data which concluded in August of 2022. Hence, this EDA will analyse data during this period.

# %%
# using a heatmap to plot for correation
plt.figure(figsize=(14,4))
features = final_df[['mean_temp', 'no_of_rainy_days', 'maximum_rainfall_in_a_day', 'total_rainfall', 'mean_rh','total_admissions',]]

features_corr = features.corr()

sns.heatmap(features_corr, annot=True, fmt='.1g', cmap='RdBu_r')
plt.title('Heatmap of Climate Variables and Hospital Admissions', )

plt.show()

# %% [markdown]
# High correlation among rainfall data and rainfall related data should be ignored and only use one rainfall data.
#  - such as number of rain days, the amount of total rainfall
#
# Note the following correlations:
# - the moderate correlation between mean relative humidity and mean temperature with a value of -0.6.
# - the moderate correlation between mean relative humidity and total rainfall with a value of 0.6.
# - the moderate correlation between mean relative humidity and total_admissions with a value of -0.5.

# %% [markdown]
# ## 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.

# %%
# visualzing of distributions using histograms
# Using the square root rule to decide the number of bins

#fig, ax = plt.subplots(19,1, figsize=(18,4))

for i in range(19): 
    
    sns.histplot(features.iloc[:,i], bins = 20)
    plt.title(f'Distribution in {features.columns[i]}')
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# From all the individual histograms, we can obeserve the following:
#
# Normal distribution:
# - Mean sunshine hours
# - Mean air temperature
# - Number of rain days
# - Mean humidity
#
# Bimodal:
# - KK Hospital
# - IMH
# - NUH
#
# Plots with negative skew:
# - TTSH
# - SGH
#
# Plots with positive skew:
# - Total hospital admissions
# - Total rainfall
# - Max rainfall
#
# Lot of N.A values:
# - NCID
# - CDC (with positive skew)
# - SKGH
# - KTPH
# - CGH

# %% [markdown]
# ## 3. Plot and interpret boxplots.

# %%
# Separate climate variables and hospital admissions for better visualisation

# Climate data
climate = final_df.iloc[:,3:9]

# create figures
fig, axes = plt.subplots(2,3, figsize=(18,10))

ax = sns.boxplot(data = climate, y = 'mean_temp', ax = axes[0, 0])
ax.set_title('Mean Air Temperature')

ax = sns.boxplot(data = climate, y = 'no_of_rainy_days', ax = axes[0, 1])
ax.set_title('Number of Rainy Days')

ax = sns.boxplot(data = climate, y = 'maximum_rainfall_in_a_day', ax = axes[0, 2])
ax.set_title('Max. Rainfall in a Day')

ax = sns.boxplot(data = climate, y = 'total_rainfall', ax = axes[1, 0])
ax.set_title('Total Rainfall')

ax = sns.boxplot(data = climate, y = 'mean_rh', ax = axes[1, 1])
ax.set_title('Mean Relative Humidity')

ax = sns.boxplot(data = climate, y = 'mean_sunshine_hrs', ax = axes[1, 2])
ax.set_title('Mean Sunshine Hours')


# the figure title
fig.suptitle('Boxplots for climate data', size =35)

plt.show()

# %% [markdown]
# In the boxplots for climate data:
# - The mean air temperature is relatively consistent with the exception of one outlier on the lower end
#
# - The number of rainy days seems to be consistent throughout this period
#
# - Maximum rainfall in a day has multiple outliers on the higher end
#
# - Total rainfall also has multiple outliers on the higher end
#
# - Mean relative humidity has a couple of outliers on the lower end
#
# - Mean sunshine hours has a couple of outliers on the higher end.

# %%
# Hospital admission data
hospital = final_df.iloc[:,10:]

# create figures
fig, axes = plt.subplots(4,4, figsize=(24,14))

ax = sns.boxplot(data = hospital, y = 'ah', ax = axes[0, 0])
ax.set_title('Alexandra Hospital')

ax = sns.boxplot(data = hospital, y = 'cgh', ax = axes[0, 1])
ax.set_title('Changi General Hospital')

ax = sns.boxplot(data = hospital, y = 'ktph', ax = axes[0, 2])
ax.set_title('Khoo Teck Puat Hospital')

ax = sns.boxplot(data = hospital, y = 'nuh', ax = axes[0, 3])
ax.set_title('National Univeristy Hospital')

ax = sns.boxplot(data = hospital, y = 'ntfgh', ax = axes[1, 0])
ax.set_title('Ng Teng Fong General Hospital')

ax = sns.boxplot(data = hospital, y = 'skgh', ax = axes[1, 1])
ax.set_title('SengKang General Hospital')

ax = sns.boxplot(data = hospital, y = 'sgh', ax = axes[1, 2])
ax.set_title('Singapore General Hospital')

ax = sns.boxplot(data = hospital, y = 'ttsh', ax = axes[1, 3])
ax.set_title('Tan Tock Seng Hospital')

ax = sns.boxplot(data = hospital, y = 'ncid', ax = axes[2, 0])
ax.set_title('National Centre for Infectious Diseases')

ax = sns.boxplot(data = hospital, y = 'cdc', ax = axes[2, 1])
ax.set_title('Communicable Disease Centre')

ax = sns.boxplot(data = hospital, y = 'imh', ax = axes[2, 2])
ax.set_title('Institute of Mental Health')

ax = sns.boxplot(data = hospital, y = 'kkh', ax = axes[2, 3])
ax.set_title('Kandang Kerbau Women\'s and Children\'s Hospital')

ax = sns.boxplot(data = hospital, y = 'nhc', ax = axes[3, 0])
ax.set_title('National Heart Centre')


# the figure title
fig.suptitle('Boxplots for Hospital Admissions Data', size =35)

axes[3, 1].remove()
axes[3, 2].remove()
axes[3, 3].remove()

plt.tight_layout()

plt.show()

# %% [markdown]
# In the boxplots for hospital admissions data:
# - Newer hospitals and specialised centres have more outliers due to its recent operational years or being specialized in nature. These hospitals are:
#     - Ng Teng Fong General Hospital open on 30 June 2015
#     - SengKang General Hospital open on 18th Aug 2018
#     - National Centre for Infectious Diseases opened in 1907 but are specialized hospital for infectious diseases and took over operations from Communicable Disease Centre in Dec 2018.
#
# - Other hospitals are generally have a few outliers with the exception of Alexandra Hospital, it has both outliers on the upper and lower end.

# %% [markdown]
# ## 4. Plot and interpret scatter plots to view relationships between features.

# %%
# plot a pairplot for an overview
sns.pairplot(features)

plt.show()

# %% [markdown]
# From the pairplot we can observe patterns of correlation between:
# - mean relative humidity vs mean air temperature
# - mean relative humidity vs total rainfall
# - mean relative humidity vs total hospital admissions

# %%
rh_hospital = final_df[['year', 'month', 'year_month', 'mean_rh', 'total_admissions', 'ah', 'ktph', 'nuh', 'cdc', 'ntfgh', 'skgh']]

print(rh_hospital.head())
# Out:
#    year month year_month  mean_rh  total_admissions    ah  ktph   nuh  cdc  ntfgh  skgh
# 0  1987    01    1987-01     86.0             18822  2345     0  1864    0      0     0
# 1  1987    02    1987-02     79.0             19074  2188     0  1862    0      0     0
# 2  1987    03    1987-03     83.2             22173  2641     0  2584    0      0     0
# 3  1987    04    1987-04     82.8             19797  2348     0  2202    0      0     0
# 4  1987    05    1987-05     84.6             19602  2357     0  2032    0      0     0

# %%
# using a heatmap to plot for correation
plt.figure(figsize=(14,4))
features = final_df[['mean_temp', 'no_of_rainy_days', 'maximum_rainfall_in_a_day', 'total_rainfall', 'mean_rh','total_admissions',]]

features_corr = features.corr()

sns.heatmap(features_corr, annot=True, fmt='.1g', cmap='RdBu_r')
plt.title('Heatmap of Climate Variables and Hospital Admissions', )

plt.show()

# %%
# plot total admissions over the years
plt.figure(figsize=(10,6))
sns.barplot(data=final_df, x = 'year', y = 'total_admissions', errorbar=None )

plt.xticks(rotation=45)

# add information to plot
plt.title('Total Hospital Admissions From 1987')
plt.xlabel('')
plt.ylabel('Admissions')

plt.show()

# %% [markdown]
# There is a steady growth of admissions over the years with a small decrease in admissions observed in 2003.

# %%
# Group the data by year and calculate total admissions for each year
yearly_admissions = final_df.groupby(final_df['year'])['total_admissions'].sum()

# Calculate year-on-year growth rate
growth_rate = yearly_admissions.pct_change() * 100 


print('The Year on Year growth rate is: ', growth_rate.mean())
# Out:
# The Year on Year growth rate is:  1.0623837050050684

# %%
# plot total_admissions with mean_rh

fig, ax1 = plt.subplots(figsize=(10,6))

# plot relative humidity
ax1 = sns.lineplot(data=final_df, x = 'month', y='mean_rh', c='grey', ax = ax1, label = 'mean relative humidity', errorbar=None, linewidth=2.5)
ax1.set_ylabel('Mean Relative Humidity %')
ax1.set_xlabel('Year')
ax1.legend(loc='upper left')


# creating a second plot to overlay with y-axis on the right for hospital admisssions
ax2 = ax1.twinx()

ax2 = sns.lineplot(data=final_df, x = 'month', y='total_admissions', c='blue', ax = ax2, label = 'Total Admissions', errorbar=None, linewidth=2.5)

ax2.legend(loc='lower right')


ax2.set_ylabel('Hospital admissions')

fig.suptitle('Mean Relative Humidity and Total Hospital Admissions in Singapore (1987-2022)', fontsize = 20)


plt.plot()
# Out:
# []

# %% [markdown]
# Based on the lineplot over the months in the year, there is a inverse correlation movement between the total hospital admissions and relative humidity.

# %% [markdown]
# ## 5. Additional plots of your choosing.

# %%
# potting of mean_rh vs temp
plt.figure(figsize=(10,6))

# plotting of graph
sns.scatterplot(data = final_df, x= 'mean_rh', y = 'mean_temp')

# plot a regression line
sns.regplot(data=final_df, x='mean_rh', y='mean_temp',  scatter=False, color='red', label='Regression Line', ci= None)

# add plot information
plt.title('Mean Relative Humidity vs Mean Air Temperature')
plt.xlabel('Mean Relative Humidity (%)')
plt.ylabel('Mean Air Temperature Celcius')

plt.show()

# %% [markdown]
# Regression line shows the correlation of mean air temperature and relative humidity. There is a negative correlation between variables.

# %%
# potting of mean_rh vs total_rainfall
plt.figure(figsize=(10,6))

# plotting of graph
sns.scatterplot(data = final_df, x= 'mean_rh', y = 'total_rainfall')

# plot a regression line
sns.regplot(data=final_df, x='mean_rh', y='total_rainfall',  scatter=False, color='red', label='Regression Line', ci= None)

# add plot information
plt.title('Mean Relative Humidity vs Total Rainfall')
plt.xlabel('Mean Relative Humidity (%)')
plt.ylabel('Total Rainfall (mm)')

plt.show()

# %% [markdown]
# Regression line is added to total rainfall and mean relative humidity. There is a positive correlation between variables.

# %%
# hospital admissions over the years

plt.figure(figsize=(10,6))

# plotting of graph
sns.lineplot(data = final_df, x= 'month', y = 'mean_rh')


# adding vertical lines for different moonsoons
plt.axvline(x = 2, c='k', linestyle = '--')
plt.axvline(x = 5, c = 'k', linestyle = '--')
plt.axvline(x = 9, c = 'k', linestyle = '--')
plt.axvline(x = 11, c = 'k', linestyle = '--')


# add plot information
plt.title('Mean Relative Humidity Over a Year')
plt.xlabel('Months')
plt.ylabel('Mean Relative Humidity (%)')

plt.show()

# %% [markdown]
# Vertical dashed lines are reference lines that show the transition between monsoons.
# NE Monsoon - from December to early March
# Intermonsoon - from March to June
# SW Monsoon - from June to October
# Intermonsoon-  From October to December

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
#
# **Key Insight**
# - Climate variation to some extent drive transmission of outbreaks
# - Manage vulnerable patients to reduce infectious diseases
# - Manage staff rotations to ease workload
#
#
#
# **Conclusion**
# Based on the observed data, there appears to be a moderate correlation between relative humidity and hospital admissions. However, it's essential to note that while relative humidity may contribute to increased hospitalizations, outbreaks is only one of the reasons a person requires inpatient care. Incorporating climate drivers into the analysis could prove insightful in staff management and bed allocations.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
